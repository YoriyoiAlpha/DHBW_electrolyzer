# %%
import pandas as pd
import json

# %%
df = None
with open('input_registers.json') as data_file:    
    data = json.load(data_file)  
    df = pd.json_normalize(data, 'registers')

# %%
sum(df["len"]) / 8
# Out:
# 306.0

# %%
df
# Out:
#       id                              name              type  len
# 0      0                         ProjectId            UInt32   32
# 1      2                           Version            UInt16   16
# 2      3                             Patch            UInt16   16
# 3      4                           BuildId            UInt32   32
# 4      6                       MainboardId           UInt128  128
# 5     14               ChassisSerialNumber            UInt64   64
# 6     18                             state            Enum16   16
# 7     20                       Livetime[s]            UInt32   32
# 8     22                         Uptime[s]            UInt32   32
# 9    768                          warnings  Sized+Uint16[31]  528
# 10   832                            errors  Sized+Uint16[31]  528
# 11  1000                 Stack-ProductCode            UInt32   32
# 12  1002                      Stack-Cycles            UInt32   32
# ...
